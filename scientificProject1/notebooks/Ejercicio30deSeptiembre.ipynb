# %%
import seaborn as sns
import pandas as pd
#2 numericas y una no numerica
df=pd.read_csv("../data/Edificios.csv")
df2= df[["codigo_postal","lat","barrio"]]
grafico = sns.pairplot(df2,hue="barrio",palette="Spectral")

# %% [markdown]
# ## Estos graficos nos muestran la relacion en la latitud y los codigos postales, mostrando tambien a que barrio pertenecen
