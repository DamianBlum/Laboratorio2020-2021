# %%
import seaborn as sns
import pandas as pd


temperaturaMaxima=0
temperaturaMinima=100000000000000
anioConTemperaturaMaxima=0
anioConTemperaturaMinima=0
mesMasFrio=0
mesMasCaluroso=0
mesConTemperaturaMaxima=""
mesConTemperaturaMinima=""

#import statistics

#list =  [1, 2, 3, 4, 5, 6]
#mean = statistics.mean(list) HACE EL PROMEDIO
#print(mean)

mediaEnero=[]
mediaFebrero=[]
mediaMarzo=[]
mediaAbril=[]
mediaMayo=[]
mediaJunio=[]
mediaJulio=[]
mediaAgosto=[]
mediaSeptiembre=[]
mediaOctubre=[]
mediaNoviembre=[]
mediaDiciembre=[]

df=pd.read_csv("../data/historico_temperaturas.csv")

for i in df.index:
    global temperaturaMinima
    global temperaturaMaxima
    mes=df["mes"][i]
    media=df["media"][i]
    maxima=df["máxima"][i]
    minima=df["mínima"][i]
    anio=df["año"][i]
    if maxima>temperaturaMaxima: #Para conseguir el año y mes con la mayor temperatura
        temperaturaMaxima=maxima
    if minima<temperaturaMinima: #Para conseguir el año y mes con la menor temperatura
        temperaturaMinima=minima
    if mes=="Enero":
        mediaEnero.append(media)
    if mes=="Febrero":
        mediaFebrero.append(media)
    if mes=="Marzo":
        mediaMarzo.append(media)
    if mes=="Abril":
        mediaAbril.append(media)
    if mes=="Mayo":
        mediaMayo.append(media)
    if mes=="Junio":
        mediaJunio.append(media)
    if mes=="Julio":
        mediaJulio.append(media)
    if mes=="Agosto":
        mediaAgosto.append(media)
    if mes=="Septiembre":
        mediaSeptiembre.append(media)
    if mes=="Octubre":
        mediaOctubre.append(media)
    if mes=="Noviembre":
        mediaNoviembre.append(media)
    if mes=="Diciembre":
        mediaDiciembre.append(media)



#TemperaturaMaxima=df["máxima"].apply(ConseguirAñoYMesDeMaxima)
#TemperaturaMinima=df["mínima"].apply(ConseguirAñoYMesDeMinima)
#print(temperaturaMaxima)
#print(temperaturaMinima)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/prueba/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/prueba/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/prueba/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
